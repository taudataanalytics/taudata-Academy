# %% [markdown]
# <center><h2><strong><font color="blue">Social Media Analytics (SMA)</font></strong></h2></center>
# <center><h3><strong><font color="blue"><a href="https://taudata.blogspot.com">https://taudata.blogspot.com</a></font></strong></h3></center>
#
# <img alt="" src="images/covers/taudata-cover.jpg"/>
#
# <center><h2><strong><font color="blue">SMA-01: Pendahuluan Analisa Media Sosial - 01</font></strong></h2></center>
# <center><h3><strong><font color="blue"><a href="https://taudata.blogspot.com/2022/04/sma-01.html">https://taudata.blogspot.com/2022/04/sma-01.html</a></font></strong></h3></center>
# <b><center><h3>(C) Taufik Sutanto</h3></center>

# %% [markdown]
# # <center><font color="blue">Pendahuluan Analisa Media Sosial - 01</font></center>
#
# 1. Pendahuluan Analisa Media Sosial
# 2. Sekilas Privacy & Ethics Data Gathering
# 3. Scrapping Media Social & Website
#
# <center><img src="images/social-media-analytics-doodle.jpg" /></center>
#
# ><font color="green">"*I always have a basic plot outline, but I like to leave some things to be decided while I write*." ~ J. K. Rowling</font>
#
# image source: https://graphicriver.net/item/social-media-analytics-doodle-concept/25210278

# %%
import warnings; warnings.simplefilter('ignore')
import nltk

try:
    import google.colab; IN_COLAB = True
    nltk.download('popular')
except:
    IN_COLAB = False
    print("Running the code locally, please make sure all the python module versions agree with colab environment and all data/assets downloaded")

from tqdm import tqdm
"Done"
# Out:
# Running the code locally, please make sure all the python module versions agree with colab environment and all data/assets downloaded
# 'Done'

# %% [markdown]
# # <center><font color="blue">The Digital (World & Indonesia) - 2021</font></center>
#
# <center><img src="images/the-digital-world.png" /></center>
#
# ><font color="green">"*We live in a digital world, but we're fairly analog creatures*." ~ Omar Ahmad</font>

# %% [markdown]
# # <center><font color="blue">The Social Media (Indonesia - 2021)</font></center>
#
# <center><img src="images/social-media-Indonesia-2021.png"/></center>
#
# * Apa makna, informasi, atau insight yang bisa didapatkan dari statistik ini dari segi: ekonomi, pemerintahan, sosial, dsb?
#
# ><font color="green">“*What happens in Vegas stays in Vegas; what happens on Twitter stay on Google forever!*.” ~ Jure Klepic</font>

# %% [markdown]
# <center><img src="images/social-media-landscape.jpg"  width="600" height="600" /></center>
#
# ><font color="green">“*Focus on how to be social, not on how to do social*.” ~ Jay Baer, Convince & Convert</font>

# %% [markdown]
# # <center><font color="blue"> Social Media Analytics (SMA): Definisi </font></center>
#
# * SMA adalah sebuah proses pengumpulan data dari media sosial dan analisanya untuk mendapatkan "insights" atau informasi berharga untuk suatu tujuan tertentu (definisi diadopsi dari Gartner*).
#
# <center><img src="images/8_SMA.JPG" width="746" height="378" /></center>
#
# ><font color="green">“*It is important that we realize that words have meanings far beyond the dictionary definition.*.” ~ Dan Levy</font>

# %% [markdown]
# # <center><font color="blue">Social Network Analysis (SNA): Definisi</font></center>
#
# <center><img src="images/SNA_Graph_Types.png" width="495" height="313" /></center>
#
# * SNA is the process of investigating social structures through the use of networks and graph theory [Otte, Evelien; Rousseau, Ronald (2002)]
# * Terdapat berbagai macam cara untuk membentuk Graph dari data media sosial: retweet, mention, followers, friends, etc.
#
# ><font color="green">“*Social networks aren’t about Web sites. They’re about experiences*.” ~ Mike DiLorenzo</font>

# %% [markdown]
# # <center><font color="blue">Social Media Real-world Applications</font></center>
#
# <center><img src="images/social media analytics applications.png" width="861" height="236" /></center>
#
# * Customer Behaviour, Campaign Performance, Customer interest, Competitive Analysis, Customer Satisfaction, Review Analysis.
# * Business insights for investors.
# * Counter terrorism (National security/defence)
# * Health, Natural disasters mitigation, etc.
#
# ><font color="green">“*Social media is not a media. The key is to listen, engage, and build relationships*.” ~ David Alston</font>

# %% [markdown]
# # <center><font color="blue">SMA-SNA Techniques</font></center>
#
# * **SMA**: Sentiment Analysis, Topic Modelling, Gender/Age Prediction, Spatial Analysis, Hashtag Analysis, Hoax Detection, Viral Prediction, etc.
# * **SNA**: Centrality Analysis, Community Detection, recommender system, etc.
# * image source: <font color="green">**Andry Alamsyah, Budi Rahardjo - 2013**</font>
# <center><img src="images/sna-taxonomy.jpg"/></center>
#
# ><font color="green">“*Algorithms are not arbiters of objective truth and fairness simply because they're math*.” ~ Zoe Quinn</font>

# %% [markdown]
# <center><img src="images/8_SMA_Cycle.JPG" width="740" height="315" /></center>
#
# ><font color="green">“*It is good to have an end to journey toward; but it is the journey that matters, in the end*.” ~ Ursula K. Le Guin</font>

# %% [markdown]
# # <center><font color="blue">Social Media/Network Analysis Technology/Tools</font></center>
#
# * **Neo4j** - Graph Database, **Elasticsearch** - Text Search Engine & NoSQL
# * **Apache Kafka** - Handling multi stream realtime input data.
# * **Gephi** - Graph Visualization
# * **VoyantTools** - Text Visualization & Analysis
# * **NetworkX**: Python Modules - Graph Programming
# * **NLTK-Spacy**: For Text Related Analysis.
# * **Spark/Hadoop**: for big data DDDC.
# * <font color="blue">**More details here:**</font> https://taudata.blogspot.com/2020/04/dsbd-05.html
#
# <center><img src="images/meme-cartoon/technology-meme-office-space.jpg" width="420" height="278" /></center>
#
# ><font color="green">“*Any sufficiently advanced technology is indistinguishable from magic*.” ~ Arthur C. Clarke</font>

# %% [markdown]
# # <center><font color="blue"> Tantangan SMA </font></center>
#
# <center><img src="images/sma-challenge-industry.jpg" width="450" height="300" /></center>
#
# * Pendek (<strong>Short </strong>in lengths): bahkan terkadang tidak mengandung sebuah kalimat yang utuh menurut tata bahasa (grammar).
# * <strong>Noise&nbsp;</strong>: Data media sosial penuh dengan noise seperti typos (salah ketik), encoding yang tidak jamak, slang, dsb.
# * <strong>Temporal&nbsp;</strong>: Informasi yang sedang trending biasanya hanya sesaat,<br />
# 	sehingga SMA diharapkan dilakukan dengan cepat menggunakan model-model/teknik-teknik analisa data yang efisien
# * <strong>High-dimensional</strong> : Data di Media Sosial (Teks, Gambar, Video, Suara, dsb) adalah data tidak terstruktur berdimensi tinggi.
# * <strong>Fine-grained</strong> : Data di media sosial berasal dari banyak user yang masing-masingnya bisa jadi membahas beberapa topik yang berbeda. Sehingga komunitas (kelompok), topik, maupun klasifikasi yang ada menjadi besar (fine-grained).
# * <strong>Large in volume</strong>&nbsp;&amp; <strong>High velocity</strong>:&nbsp; Data yang sangat besar dan bertambah besar dengan cepat.
# * <strong>A lot of external Information</strong> : Informasi terkadang lebih banyak terkandung dari luar (eksternal) seperti url website, video, atau hal lain yang dibagikan oleh pengguna media sosial.
#
# ><font color="green">“*If you make customers unhappy in the physical world, they might each tell 6 friends. If you make customers unhappy on the Internet, they can each tell 6,000 friends*.” ~ Jeff Bezos</font>

# %% [markdown]
# # <center><font color="blue">Digital Data Gathering (DDG): Scrapping, Crawling, & Streaming</font></center>
#
# <center><img src="images/scrapping-crawling-streaming.png" width="693" height="295" /></center>
#
# * **Streaming**: teknik pengiriman data (media) secara kontinu & real-time.
#
# ><font color="green">“*Data is a precious thing and will last longer than the systems themselves*.” ~ Tim Berners-Lee</font>

# %% [markdown]
# # <center><font color="blue">Ethics & Regulation</font></center>
#
# * Scrapping secara umum (minimal) tidak etis (bisa jadi ilegal). Mengapa? karena scraping mirip DDOS attack yang akan memberatkan server atau bahkan membuat server berhenti berfungsi normal. Program scraping juga memungkinkan akan mengakses data yang tidak dimaksudkan untuk konsumsi publik.
# * Satu-satunya saat dimana scraping boleh dilakukan adalah saat sang pelaku/programer menghormati “robots.txt” yang telah diberikan oleh web administrator. Atau lebih baik lagi adalah menggunakan API (Application Program Interface) yang diberikan oleh provider (website/medsos) lalu melakukan crawling.
# * Yakinkan untuk membaca ToS (Terms of Sevice) dengan baik.
# * <font color="blue">**More details here:**</font> https://taudata.blogspot.com/2020/04/apakah-scraping-websitemedia-sosial.html
#
# <center><img src="images/Data Ethics and Law.png" width="619" height="287" /></center>
#
# ><font color="green">“*Good regulation should be conducive to business and to customer protection*.” ~ Jamie Dimon</font>

# %% [markdown]
# <h2 id="Aturan-twitter">Aturan, bentuk data, &amp; error codes twitter</h2>
#
# <ol>
# 	<li>
# 	<p><a href="https://dev.twitter.com/rest/public/rate-limiting" target="_blank">https://</a><a href="https://dev.twitter.com/rest/public/rate-limiting" target="_blank">dev.twitter.com/rest/public/rate-limiting</a></p>
# 	</li>
# 	<li>
# 	<p><a href="https://dev.twitter.com/overview/terms/agreement-and-policy" target="_blank">https://dev.twitter.com/overview/terms/agreement-and-policy</a></p>
# 	</li>
# 	<li>
# 	<p><a href="https://dev.twitter.com/overview/api/response-codes" target="_blank">https://</a><a href="https://dev.twitter.com/overview/api/response-codes" target="_blank">dev.twitter.com/overview/api/response-codes</a></p>
# 	</li>
# 	<li>
# 	<p><a href="https://dev.twitter.com/overview/api/tweets" target="_blank">https://</a><a href="https://dev.twitter.com/overview/api/tweets" target="_blank">dev.twitter.com/overview/api/tweets</a></p>
# 	</li>
# </ol>

# %% [markdown]
# # <center><font color="blue">Mengapa API Keys penting untuk dijaga seperti Username & Password?</font></center>
#
# <center><img src="images/meme-cartoon/meme-i-can-haz-api-key.jpg" width="301" height="314" /></center>

# %% [markdown]
# # <center><font color="blue">Crawling twitter</font></center>
#
# <center><img src="images/Digital_Media_Crawling_.png" width="501" height="514" /></center>
#
# * image source: https://www.promptcloud.com/blog/scraping-social-media-data-for-sentiment-analysis/

# %% [markdown]
# # <center><font color="blue">Json Files</font></center>
#
# <ul>
# 	<li>Populer digunakan untuk data dari Media Sosial dan NoSQL</li>
# 	<li>Portable: File Json memuat nama variabel dan nilainya (tidak seperti XML)</li>
# 	<li>Plain Text</li>
# 	<li>Schemaless: Setiap record tidak harus memiliki jumlah field yang tetap seperti csv</li>
# 	<li>JSON isomorfis dengan &quot;Dictionary&quot; di Python</li>
# 	<li>Contoh struktur file json:</li>
# </ul>
#
# <img style="undefined: undefined;" src="images/json.png" alt="" width="194" height="204" />

# %% [markdown]
# <img alt="" src="images/SMA-Sampling.png" />

# %% [markdown]
# # <center><font color="blue">Spatial Analysis di twitter menggunakan Google Maps API dan twitter GeoCode</font></center>
#
# * Google Maps API (gratis 40.000 query/bulan) dan bisa dijalankan langsung dalam program Python
# * Alternatif: https://www.gps-coordinates.net/ | https://www.latlong.net/convert-address-to-lat-long.html
#
# <center><img src="images/sma-spasial.png" width="568" height="325" /></center>

# %%
# https://www.latlong.net/convert-address-to-lat-long.html

alamat = "FST UIN Jakarta"
lat = '-6.379800'
lon = '106.807083'

"Done"

# %% [markdown]
# # <center><font color="blue">Pada kasus nyata data disimpan ke database - Big Data</font></center>
#
# * Contoh aplikasi di Elasticsearch
#
# <center><img style="undefined: undefined;" src="images/elasticsearch.png" alt="" width="471" height="266" /></center>

# %% [markdown]
# # <center><font color="blue">Big Data semakin Mudah</font></center>
#
# * Easy Scalability: Auto balancing & distributing
# * Easy replica (Backup)
# * Easy Monitoring & Visualization: dashboard
# * Not easy? .... Statistika/Teori di balik Big Data.
#
# <p><img src="images/illustrated-screenshot-hero-kibana.png" /></p>

# %% [markdown]
# # <center><font color="blue">Preprocessing data Teks</font></center>
#
# ### Pembahasan Detail: https://taudata.blogspot.com/2020/04/nlptm-01.html
#
# <p><img src="images/TextMining_PipeLine.jpg" alt="" width="584" height="228" /></p>

# %% [markdown]
# # <center><font color="blue">HashTag Analysis</font></center>
#
# * Frequency-Based
# * Bisa ditambahkan analisa hashtags analysis ini dari waktu ke waktu

# %% [markdown]
# # Web Scrapping?

# %%
import urllib.request
from bs4 import BeautifulSoup as bs

URL = 'https://fst.uinjkt.ac.id'
Doc = urllib.request.urlopen(URL).read()
Doc = bs(Doc,'lxml').text
print(Doc)
# Out:
# Faculty of Science and Technology Syarif Hidayatullah State Islamic University
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# About
#
# History
# Vision, Mission, Goals and Motto
# Dean's Foreword
# Strategic Plan
# Work Program
# Organization
#
#
#
# Education
#
#
# Research
#
#
# Community Service
#
#
# Alumni
#
#
# Document
#
#
# Directory
#
#
#
#  EN
#
#
#
#
#  ID
#
#
#
#
#  AR
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Inauguration of Innovation Impact Hub by Maxy Academy
# A Center for Student Innovation and Collaboration at UIN Syarif Hidayatullah, Jakarta
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# International Conference
# CITSM 2024: 12TH International Conference on Cyber and IT Service Management Comes to Batam, Presenting the Latest Innovations in the Digital Age
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Student Activities
# Collaboration of Mining Engineering FST UIN Syarif Hidayatullah and PT ANTAM: Student Field Trip to UBPE Pongkor
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Smart Urban Farming
# An Efficient and Environmentally Friendly Urban Farming Solution: Agribusiness Study Program Hydroponic Vegetable Cultivation in the Hallway of FST Building
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Scholarship Opportunities
# PANDI Launches Scholarship Program for FST Students at UIN Syarif Hidayatullah Jakarta to Support Technologist Education
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cooperation between FST UIN Jakarta and MAXY Academy
# Innovation Impact HUB Ready to Print Student Talents in the Digital and Entrepreneurship Fields
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Initiation of Cooperation
# Discussion of FST UIN Jakarta's Collaboration with PT Tie Ups International
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# International Cooperation
# UIN Syarif Hidayatullah Jakarta and Mapua University Philippines Establish International Cooperation in Asian Science Deans Forum in Philippines
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# International Accreditation ASIIN
# Visitation of the ASIIN International Accreditation Assessor Team for the Life Science Cluster, Faculty of Science and Technology, UIN Syarif Hidayatullah Jakarta
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Studium General
# Physics Study Program Holds Studium General on Geosciences and Further Studies in Utrecht, Netherlands
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Discussion of Cooperation
# Discussion between FST UIN Jakarta and RMUTT Thailand: Opportunities for Research Collaboration, Academic Competition, and Student Exchange
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Student Activities
# Release of Faculty of Science and Technology Students for Student Mobility Outbound (SMO) Thai Cross Cultural Program Thailand 2023
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Signing of Cooperation
# Signing of Cooperation between FST UIN Jakarta with Al Azhar University Indonesia (UAI) and Republika Media Mandiri
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Signing of Cooperation
# Signing of Cooperation between FST UIN Jakarta and PT Edublast Teknologi Indonesia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cooperation
# FST UIN Jakarta Visit to UNPAM to Explore Cooperation in Data Science and Language Learning Applications
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Student Release
# Student Mobility Outbound (SMO) Thai Cross Cultural Program Thailand 2023
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Discussion of Cooperation
# FST UIN Jakarta with International Islamic University Malaysia (UIIM)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Guest Lecturer
# Artificial Intelligence and The Future of Islam
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Workshop
# goIT Program Student Innovation Workshop
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Collaboration Discussion
# Faculty of Science and Technology, Universitas Islam Negeri Jakarta and Tata Consultancy Services
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cooperation
# Faculty of Science and Technology Jakarta State Islamic University with Huawei Indonesia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Discussion of Cooperation
#  FST UIN Jakarta with FT UI and CCIT FTUI
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Exploration of Cooperation
# Faculty of Science and Technology UIN Jakarta with Artificial Intelligence Center Indonesia, Faculty of Mathematics and Natural Sciences UI
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Cooperation Agreement
#  FST and FITK UIN Jakarta with Tata Consultancy Services
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Student Release
# Agribusiness Students Depart to Germany for Working Holiday Program
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Signing of Cooperation Agreement
# CITSM 2023 Activities at Valaya Alongkorn Rajabhat University
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Student Internship
# Agribusiness Students Conduct Internship to Japan
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Signing of Cooperation Agreement
#   Faculty of Science and Technology Jakarta State Islamic University and Raja Ali Haji Maritime University (UMRAH)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Discussion of Cooperation
# Faculty of Science and Technology, Jakarta State Islamic University and EMLIKU Smart Technology
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Discussion of Cooperation
# Faculty of Science and Technology of Jakarta State Islamic University and Valaya Alongkorn Rajabhat University
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Discussion of Cooperation
# Faculty of Science and Technology of Jakarta State Islamic University and Suan Sunadha Rajabhat University
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Data & Facts from the Faculty of Science and Technology
#
#
#
#
# 10
# Study program
#
#
#
#
# 11
# Expert
#
#
#
#
# 3660
# Student
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Quick Access
#
#
#
#
#
#                         PMB Registration 2025
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# AIS
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 e-Letter
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Academic Guidelines
#
#
#
#
#
#
#
#
#
#
#
#
#
# Partner
#
#
#
#
#
#
#
#
#
#
#
#
#
# E-Journal SI
#
#
#
#
#
#
#
#
#
#
#
#
#
# E-Journal TI
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 Library
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 E-Kinerja
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 BKD
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Latest news
#
#
#                             Other News
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     17 April 2025
#
#
#
#
#                                     Inauguration of Saintek Hub Faculty of Science and Technology UIN Jakarta
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     15 April 2025
#
#
#
#
#                                     Guest Lecturer Agribusiness Study Program Faculty of Science and Technology UIN Syarif Hidayatullah Jakarta
#
#
#
#
#
#
#
#
# Civitas Articles
#
#
#                             Other Articles
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Education
# Study
# Community Service
#
#
#
#
#
#
# Education
# The Faculty of Science and Technology (FST) offers pure technology, informatics and exact science education. Among the study programs it offers are Information Systems, Information Engineering, Chemistry, Biology, and others. Apart from the undergraduate level, FST also offers education at the postgraduate level (master's/S2).
#
# More
#
#
#
#
#
# Study
# Starting from the vision, mission and objectives of FST UIN Jakarta, FST plays an active role in encouraging community independence in managing natural resources based on Information Technology and integrating Islamic values. As an academic institution, FST UIN Jakarta also plays an active role in providing solutions to various environmental, health and food problems related to academic studies on the needs, challenges and problems faced by the community and government either directly or indirectly. Support and commitment from stakeholders and researchers are key to the successful implementation of the PKM strategy. The involvement of all key partners will always be expected for better PkM benefits in an effort to improve the degree of community life.
#
# More
#
#
#
#
#
# Community Service
# Starting from the vision, mission and objectives of FST UIN Jakarta, FST plays an active role in encouraging community independence in managing natural resources based on Information Technology and integrating Islamic values. As an academic institution, FST UIN Jakarta also plays an active role in providing solutions to various environmental, health and food issues related to academic studies of needs, challenges or problems faced by society and the government, both directly and indirectly. Support and commitment from stakeholders and researchers is the key to successful implementation of the PKM strategy.
#
# More
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Announcement
#
#
#                             Other Announcements
#
#
#
#
#
#
# Agenda
#
#
#                             Other Agenda
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contact us
#
#
#
#
#
#
#
# Phone number
# (021)7493606
#
#
#
#
#
#
#
# Email address
# fst[@]apps.uinjkt.ac.id
#
#
#
#
#
#
#
# Campus Address 1
# Jalan Ir. H. Djuanda No. 95 Ciputat, South Tangerang City 15412
#
#
#
#
#
#
#
#
# Social media
#
#
#
#
#
#
#
#
#
# ei reporting
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2025 © Syarif Hidayatullah State Islamic University Jakarta

# %% [markdown]
# # Loading Local Documents
#
# * pip install PyPDF2

# %%
import PyPDF2

# Open the PDF file
with open('data/PDF/contoh.pdf', "rb") as file:
    reader = PyPDF2.PdfReader(file)
    # Read text from the first page
    page = reader.pages[0]
    text = page.extract_text()
    print(text)
# Out:
# BUTIR -BUTIR PEDOMAN PENGHAYATAN DAN PENGAMALAN PANCASILA
#
#
# Lima asas dalam Pancasila dijabarkan menjadi 36 butir pengamalan, sebagai pedoman praktis bagi
# pelaksanaan Pancasila.
#
# Butir -butir Pancasila ditetapkan dalam Ketetapan MPR No. II/MPR/1978 tentang Ekaprasetia
# Pancakarsa.
#
# I. SILA PERTAMA : KETUHANAN YANG MAHA ESA
# 1. Percaya dan Takwa kepada Tuhan Yang Maha Esa sesuai dengan agama dan kepercayaan
# masing -masing menurut dasar kemanusiaan yang adil dan beradab.
# 2. Hormat menghormati dan bekerjas ama antar pemeluk agama & penganut -penganut
# kepercayaan yang berbeda -beda sehingga terbina kerukunan hidup.
# 3. Saling hormat -menghormati kebebasan menjalankan ibadah sesuai dengan agama dan
# kepercayaannya.
# 4. Tidak memaksakan suatu agama dan kepercayaan ke pada orang lain.
#
# II. SILA KEDUA : KEMANUSIAAN YANG ADIL DAN BERADAB
# 1. Mengakui persamaan derajat, persamaan hak dan persamaan kewajiban antara sesama
# manusia.
# 2 Saling mencintai sesama manusia.
# 3 Mengembangkan sikap tenggang rasa.
# 4. Tidak semena -mena t erhadap orang lain.
# 5. Menjunjung tinggi nilai -nilai kemanusiaan.
# 6. Gemar melakukan kegiatan kemanusiaan.
# 7. Berani membela kebenaran dan keadilan.
# 8. Bangsa Indonesia merasa dirinya sebagai bagian dari seluruh umat manusia, karena itu
# kembangkan sikap hormat -menghormati dan bekerjasama dengan bangsa lain.
#
# III. SILA KETIGA : PERSATUAN INDONESIA
# 1. Menempatkan kesatuan, persatuan, kepentingan, dan keselamatan bangsa dan negara di atas
# kepentingan pribadi atau golongan.
# 2. Rela berkorban untuk kepentingan  bangsa dan negara.
# 3. Cinta Tanah Air dan Bangsa.
# 4. Bangga sebagai Bangsa Indonesia dan bertanah Air Indonesia.
# 5. Memajukan pergaulan demi persatuan dan kesatuan bangsa yang ber -Bhinneka Tunggal Ika.
#
# IV. SILA KEEMPAT : KERAKYATAN YANG DIPIMPIN OLEH HIK MAT KEBIJAKSANAAN DALAM
# PERMUSYAWARATAN / PERWAKILAN
# 1 Mengutamakan kepentingan Negara dan masyarakat.
# 2. Tidak memaksakan kehendak kepada orang lain.
# 3 Mengutamakan musyawarah dalam mengambil keputusan untuk kepentingan bersama.
# 4. Musyawarah untuk mencap ai mufakat diliputi semangat kekeluargaan.
# 5. Dengan itikad baik dan rasa tanggung jawab menerima dan melaksanakan hasil musyawarah.
# 6. Musyawarah dilakukan dengan akal sehat dan sesuai dengan hati nurani yang luhur.
# 7. Keputusan yang diambil harus dapat d ipertanggung -jawabkan secara moral kepada Tuhan Yang
# Maha Esa, menjunjung tinggi harkat dan martabat manusia serta nilai -nilai kebenaran dan
# keadilan.
#
# V. SILA KELIMA : KEADILAN SOSIAL BAGI SELURUH RAKYAT INDONESIA
# 1 Mengembangkan perbuatan  luhur yang mencerminkan sikap dan suasana kekeluargaan dan
# gotong -royong.
# 2. Bersikap adil.
# 3. Menjaga keseimbangan antara hak dan kewajiban.
# 4. Menghormati hak -hak orang lain.
# 5. Suka memberi pertolongan kepada orang lain.
# 6. Menjauhi sikap pemerasan terhadap orang lain.
# 7. Tidak bersifat boros.
# 8. Tidak bergaya hidup mewah.
# 9. Tidak melakukan perbuatan yang merugikan kepentingan umum.
# 10. Suka bekerja keras.
# 11. Menghargai hasil karya orang lain.
# 12. Bersama -sama berusaha mewujudkan kemajuan yang merata dan berkead ilan sosial.

# %% [markdown]
# # <center><font color="blue"> Akhir Modul "Pendahuluan Analisa Media Sosial - 01"</font></center>
#
# <hr />
